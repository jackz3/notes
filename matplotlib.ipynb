# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#from matplotlib.pylab import rcParams
#rcParams['figure.figsize'] = 15, 6
plt.rcParams['figure.figsize'] = 13,9
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('./loan_train.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-532c629bdb72> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('./loan_train.csv')
#       4 df.head()
#
# ~/.local/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
#Plots in matplotlib reside within a figure object, use plt.figure to create new figure
fig=plt.figure()
#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)
ax.hist(df['ApplicantIncome'],bins = 50,color='#8cdcb4')
#df['ApplicantIncome'].hist(bins=40,label='lala')
#plt.hist(df['ApplicantIncome'], bins=50)

plt.title('ApplicantIncome distribution')
plt.xlabel('income')
plt.ylabel('count')
ax.set_xlabel('Gender')
ax.set_ylabel('Sum of Sales')
ax.set_title("Gender wise Sum of Sales")
plt.show()
# Cumulative Histogram (Discrete Estimated CDF)
plt.hist(df['ApplicantIncome'], bins=50, cumulative=True);

# %%
plt.plot(df['ApplicantIncome'])
plt.plot(df['CoapplicantIncome']);

# %%
#ax.boxplot(df['ApplicantIncome'])
plt.boxplot(df['ApplicantIncome']);

# %%
var = df.groupby('Gender').ApplicantIncome.sum()
var.plot(kind='bar')
#country_array = np.arange(5)
#plt.bar(country_array, mean_salary)
#plt.xticks(country_array, country)

# %%
var = df.groupby('Education').ApplicantIncome.sum()
var.plot(kind='line')b
#plt.plot(df['LoanAmount'], df['ApplicantIncome'] )
# Out:
#   File "<ipython-input-7-5c2c3fca3c41>", line 2
#     var.plot(kind='line')b
#                          ^
# SyntaxError: invalid syntax

# %%
var = df.groupby(['Gender','Education']).ApplicantIncome.sum()
var.unstack().plot(kind='bar',stacked=True,  color=['red','blue'], grid=False)

# %%
#ax.scatter(df['LoanAmount'],df['ApplicantIncome']) #You can also add more variables here to represent color and size.
plt.scatter(df['LoanAmount'],df['ApplicantIncome'], c='#ef5423', label='Scatter Plot');
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(df['LoanAmount'],df['ApplicantIncome'], s=df['CoapplicantIncome']) # Added third variable as size of the bubble
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
var=df.groupby(['Gender']).sum().stack()
temp=var.unstack()
type(temp)
x_list = temp['ApplicantIncome']
label_list = temp.index
pyplot.axis("equal") #The pie chart is oval by default. To make it a circle use pyplot.axis("equal")
#To show the percentage of each pie slice, pass an output format to the autopctparameter 
plt.pie(x_list,labels=label_list,autopct="%1.1f%%") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-068c2b0c5f28> in <module>()
#       4 x_list = temp['ApplicantIncome']
#       5 label_list = temp.index
# ----> 6 pyplot.axis("equal") #The pie chart is oval by default. To make it a circle use pyplot.axis("equal")
#       7 #To show the percentage of each pie slice, pass an output format to the autopctparameter
#       8 plt.pie(x_list,labels=label_list,autopct="%1.1f%%")
#
# NameError: name 'pyplot' is not defined

# %%
#Generate a random number, you can refer your data values also
data = np.random.rand(4,2)
rows = list('1234') #rows categories
columns = list('MF') #column categories
fig,ax=plt.subplots()
#Advance color controls
ax.pcolor(data,cmap=plt.cm.Reds,edgecolors='k')
ax.set_xticks(np.arange(0,2)+0.5)
ax.set_yticks(np.arange(0,4)+0.5)
# Here we position the tick labels for x and y axis
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
#Values against each labels
ax.set_xticklabels(columns,minor=False,fontsize=20)
ax.set_yticklabels(rows,minor=False,fontsize=20)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
